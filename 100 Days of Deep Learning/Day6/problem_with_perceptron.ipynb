# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
or_data = pd.DataFrame()
and_data = pd.DataFrame() 
xor_data = pd.DataFrame()

# %%
or_data['input1'] = [1,1,0,0]
or_data['input2'] = [1,0,1,0]
or_data['output'] = [1,1,1,0]

# %%
and_data['input1'] = [1,1,0,0]
and_data['input2'] = [1,0,1,0]
and_data['output'] = [1,0,0,0]

# %%
xor_data['input1'] = [1,1,0,0]
xor_data['input2'] = [1,0,1,0]
xor_data['output'] = [0,1,1,0]

# %%
and_data
# Out:
#    input1  input2  output
# 0       1       1       1
# 1       1       0       0
# 2       0       1       0
# 3       0       0       0

# %%
sns.scatterplot(x= or_data['input1'], y= or_data['input2'], hue= or_data['output'], s=200)
# Out:
# <Axes: xlabel='input1', ylabel='input2'>

# %%
and_data
# Out:
#    input1  input2  output
# 0       1       1       1
# 1       1       0       0
# 2       0       1       0
# 3       0       0       0

# %%
sns.scatterplot(x= and_data['input1'], y= and_data['input2'], hue= and_data['output'], s=200)
# Out:
# <Axes: xlabel='input1', ylabel='input2'>

# %%
xor_data
# Out:
#    input1  input2  output
# 0       1       1       0
# 1       1       0       1
# 2       0       1       1
# 3       0       0       0

# %%
sns.scatterplot(x= xor_data['input1'], y= xor_data['input2'], hue= xor_data['output'], s=200)
# Out:
# <Axes: xlabel='input1', ylabel='input2'>

# %%
# for the xor we cannot have a line that will seperate the classes of the 0 and 1 instances

# %%
from sklearn.linear_model import Perceptron 
clf1 = Perceptron() 
clf2 = Perceptron() 
clf3 = Perceptron()

# %%
clf1.fit(and_data.iloc[:,0:2].values, and_data.iloc[:,-1].values)
# Out:
# Perceptron()

# %%
clf2.fit(or_data.iloc[:,0:2].values, or_data.iloc[:,-1].values)
# Out:
# Perceptron()

# %%
clf3.fit(xor_data.iloc[:,0:2].values, and_data.iloc[:,-1].values)
# Out:
# Perceptron()

# %%
x = np.linspace(-1,1,5)

# %%
y = -x+1

# %%
plt.plot(x,y)
sns.scatterplot(x= and_data['input1'], y= and_data['input2'], hue = and_data['output'], s=200)
# Out:
# <Axes: xlabel='input1', ylabel='input2'>

# %%
# !pip install mlxtend
# Out:
# Requirement already satisfied: mlxtend in c:\users\sapko\miniconda3\envs\100days\lib\site-packages (0.23.1)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\sapko\miniconda3\envs\100days\lib\site-packages (from mlxtend) (1.12.0)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\sapko\miniconda3\envs\100days\lib\site-packages (from mlxtend) (1.26.4)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\sapko\miniconda3\envs\100days\lib\site-packages (from mlxtend) (2.2.1)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\sapko\miniconda3\envs\100days\lib\site-packages (from mlxtend) (1.4.1.post1)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\sapko\miniconda3\envs\100days\lib\site-packages (from mlxtend) (3.8.3)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\sapko\miniconda3\envs\100days\lib\site-packages (from mlxtend) (1.3.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sapko\miniconda3\envs\100days\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\sapko\miniconda3\envs\100days\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sapko\miniconda3\envs\100days\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\sapko\miniconda3\envs\100days\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\sapko\miniconda3\envs\100days\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\sapko\miniconda3\envs\100days\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sapko\miniconda3\envs\100days\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sapko\miniconda3\envs\100days\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sapko\miniconda3\envs\100days\lib\site-packages (from pandas>=0.24.2->mlxtend) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sapko\miniconda3\envs\100days\lib\site-packages (from pandas>=0.24.2->mlxtend) (2024.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\sapko\miniconda3\envs\100days\lib\site-packages (from scikit-learn>=1.0.2->mlxtend) (3.3.0)
# Requirement already satisfied: six>=1.5 in c:\users\sapko\miniconda3\envs\100days\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)

# %%
from mlxtend.plotting import plot_decision_regions

plot_decision_regions(xor_data.iloc[:,0:2].values,xor_data.iloc[:,-1].values, clf=clf3, legend=2)
# Out:
# <Axes: >

# %%
# it cannot get the proper decision boundary for the data which is not linearly seperable
